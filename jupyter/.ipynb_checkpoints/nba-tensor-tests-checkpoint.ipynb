# %%
import tensorflow as tf
from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
LABELS = [True, False]
# True = home win, False = away win
LABEL_COLUMN = "WINorLOSS"

TEAM_DICT = {
             "MIL" : "Milwaukee Bucks",
             "MIA" : "Miami Heat",
             "BOS" : "Boston Celtics",
             "TOR" : "Toronto Raptors",
             "PHI" : "Philidelphia 76ers",
             "IND" : "Indiana Pacers",
             "BRK" : "Brooklyn Nets",
             "ORL" : "Orlando Magic",
             "CHO" : "Charlotte Hornets",
             "CHI" : "Chicago Bulls",
             "DET" : "Detroit Pistons",
             "WAS" : "Washington Wizards",
             "CLE" : "Cleveland Cavaliers",
             "NYK" : "New York Knicks",
             "ATL" : "Atlanta Hawks",
             "LAL" : "Los Angeles Lakers",
             "DEN" : "Denver Nuggets",
             "HOU" : "Houston Rockets",
             "LAC" : "Los Angeles Clippers",
             "DAL" : "Dallas Mavericks",
             "UTA" : "Utah Jazz",
             "OKC" : "Oklahoma City Thunder",
             "POR" : "Portland Trail Blazers",
             "SAS" : "San Antonio Spurs",
             "SAC" : "Sacramento Kings",
             "PHO" : "Phoenix Suns",
             "MEM" : "Memphis Grizzlies",
             "MIN" : "Minnesota Timberwolves",
             "NOP" : "New Orleans Pelicans",
             "GSW" : "Golden State Warriors"
            }

BOOL_DICT = {1 : True, 0 : False}

# %%
#19-20
data3 = pd.read_csv("../data/games/nba-games-2019-oct-nov-dec.txt", index_col=4)
data3 = data3.drop(columns=['Start (ET)','Unnamed: 6','Unnamed: 7', 'Attend.', 'Notes'])

games2015 = pd.read_csv("../data/games/nba-games-14-15.txt",index_col=4)
games2015 = games2015.drop(columns=['Start (ET)','Unnamed: 6','Unnamed: 7', 'Attend.', 'Notes'])

games2016 = pd.read_csv("../data/games/nba-games-15-16.txt",index_col=4)
games2016 = games2016.drop(columns=['Start (ET)','Unnamed: 6','Unnamed: 7', 'Attend.', 'Notes'])

games2017 = pd.read_csv("../data/games/nba-games-16-17.txt",index_col=4)
games2017 = games2017.drop(columns=['Start (ET)','Unnamed: 6','Unnamed: 7', 'Attend.', 'Notes'])

games2018 = pd.read_csv("../data/games/nba-games-17-18.txt",index_col=4)
games2018 = games2018.drop(columns=['Start (ET)','Unnamed: 6','Unnamed: 7', 'Attend.', 'Notes'])

games2019 = pd.read_csv("../data/games/nba-games-18-19.txt",index_col=4)
games2019 = games2019.drop(columns=['Start (ET)','Unnamed: 6','Unnamed: 7', 'Attend.', 'Notes'])

#season stats
data4 = pd.read_csv("../data/league-stats/team-per-game.txt", index_col=1)
data4 = data4.drop(columns=['Rk', 'G', 'MP'])

data2015 = pd.read_csv("../data/league-stats/team-per-game-14-15.txt",index_col=1)
data2015 = data2015.drop(columns=['Rk','G', 'MP'])

data2016 = pd.read_csv("../data/league-stats/team-per-game-15-16.txt",index_col=1)
data2016 = data2016.drop(columns=['Rk','G', 'MP'])

data2017 = pd.read_csv("../data/league-stats/team-per-game-16-17.txt",index_col=1)
data2017 = data2017.drop(columns=['Rk','G', 'MP'])

data2018 = pd.read_csv("../data/league-stats/team-per-game-17-18.txt",index_col=1)
data2018 = data2018.drop(columns=['Rk','G', 'MP'])

data2019 = pd.read_csv("../data/league-stats/team-per-game-18-19.txt",index_col=1)
data2019 = data2019.drop(columns=['Rk','G', 'MP'])

dataOppStats2015 = pd.read_csv("../data/league-stats/opponent-stats-14-15.txt", index_col=1)
dataOppStats2015 = dataOppStats2015.drop(columns=['Rk', 'G', 'MP'])

dataOppStats2016 = pd.read_csv("../data/league-stats/opponent-stats-15-16.txt", index_col=1)
dataOppStats2016 = dataOppStats2016.drop(columns=['Rk', 'G', 'MP'])

dataOppStats2017 = pd.read_csv("../data/league-stats/opponent-stats-16-17.txt", index_col=1)
dataOppStats2017 = dataOppStats2017.drop(columns=['Rk', 'G', 'MP'])

dataOppStats2018 = pd.read_csv("../data/league-stats/opponent-stats-17-18.txt", index_col=1)
dataOppStats2018 = dataOppStats2018.drop(columns=['Rk', 'G', 'MP'])

dataOppStats2019 = pd.read_csv("../data/league-stats/opponent-stats-18-19.txt", index_col=1)
dataOppStats2019 = dataOppStats2019.drop(columns=['Rk', 'G', 'MP'])

dataOppStats2020 = pd.read_csv("../data/league-stats/opponent-stats.txt", index_col=1)
dataOppStats2020 = dataOppStats2020.drop(columns=['Rk', 'G', 'MP'])

nba_games = [data3,games2015,games2016,games2017,games2018,games2019]

for s in nba_games:
    s["HomeWin"] = s["PTS"] > s["PTS.1"]
    
data3 = data3.drop(columns=["PTS","PTS.1"])
games2015 = games2015.drop(columns=["PTS","PTS.1"])
games2016 = games2016.drop(columns=["PTS","PTS.1"])
games2017 = games2017.drop(columns=["PTS","PTS.1"])
games2018 = games2018.drop(columns=["PTS","PTS.1"])
games2019 = games2019.drop(columns=["PTS","PTS.1"])

away_sets = [games2016,games2017,data3]
home_sets = [games2015,games2018,games2019]
for s in home_sets:
    s["Home"] = 1

for s in away_sets:
    s["Home/Neutral"] = s.index
    s.index = s["Visitor/Neutral"]
    s["Home"] = 0
    s["HomeWin"] = ~s["HomeWin"]
    
col = ["Date", "Home/Neutral", "HomeWin", "Home"]
games2016 = games2016.drop(columns=["Visitor/Neutral"])
games2016 = games2016.reindex(columns=col)
games2017 = games2017.drop(columns=["Visitor/Neutral"])
games2017 = games2017.reindex(columns=col)
data3 = data3.drop(columns=["Visitor/Neutral"])
data3 = data3.reindex(columns=col)
                              
#input for prediction

#season stats (past 5 games?), opponent, home/away

#input: team stats (weighted average), opp stats (weighted average), home/away, rest days

# %%
d5 = data3.join(data4,lsuffix="_d3", rsuffix="_d4")
d6 = d5.join(data4, on='Home/Neutral', lsuffix="_A",rsuffix="_B")
d7 = d6.join(dataOppStats2020)
d8 = d7.join(dataOppStats2020, on='Home/Neutral', lsuffix='_AOppStat', rsuffix='_BOppStats')
# has teams, date, winner, all relevant stats: need to add rest days, recency bias, any other stats I may want (injury?)

d5 = games2016.join(data2016,lsuffix="_d3",rsuffix="_d4")
d6 = d5.join(data2016, on='Home/Neutral', lsuffix="_A",rsuffix="_B")
d7 = d6.join(dataOppStats2016)
d9 = d7.join(dataOppStats2016, on='Home/Neutral', lsuffix='_AOppStat', rsuffix='_BOppStats')

d5 = games2015.join(data2015,lsuffix="_d3",rsuffix="_d4")
d6 = d5.join(data2015, on='Visitor/Neutral', lsuffix="_A",rsuffix="_B")
d7 = d6.join(dataOppStats2015)
d10 = d7.join(dataOppStats2015, on='Visitor/Neutral', lsuffix='_AOppStat', rsuffix='_BOppStats')
print(d10)
d5 = games2017.join(data2017,lsuffix="_d3",rsuffix="_d4")
d6 = d5.join(data2017, on='Home/Neutral', lsuffix="_A",rsuffix="_B")
d7 = d6.join(dataOppStats2017)
d11 = d7.join(dataOppStats2017, on='Home/Neutral', lsuffix='_AOppStat', rsuffix='_BOppStats')

d5 = games2018.join(data2018,lsuffix="_d3",rsuffix="_d4")
d6 = d5.join(data2018, on='Visitor/Neutral', lsuffix="_A",rsuffix="_B")
d7 = d6.join(dataOppStats2018)
d12 = d7.join(dataOppStats2018, on='Visitor/Neutral', lsuffix='_AOppStat', rsuffix='_BOppStats')

d5 = games2019.join(data2019,lsuffix="_d3",rsuffix="_d4")
d6 = d5.join(data2019, on='Visitor/Neutral', lsuffix="_A",rsuffix="_B")
d7 = d6.join(dataOppStats2019)
d13 = d7.join(dataOppStats2019, on='Visitor/Neutral', lsuffix='_AOppStat', rsuffix='_BOppStats')

check = d8.columns
d8 = pd.concat([d8,d9,d10,d11,d12,d13],sort=True)
d8 = d8.reindex(columns=check)

#standardizing data
d8 = d8.drop(columns=["Home/Neutral","Date"])

# join games with season stats
# join that with season stats but on away team
# join with opponent stats
# join with opponent stats but on away team

#need to use later for ^^^^
#d8 = d8.drop(columns=['Date'])
#d9 = d9.drop(columns=['Date'])

row,col = d8.shape
d8 = d8.sample(frac=1)
a = int(row * .2)
train_data = d8.iloc[0:a]
test_data = d8.iloc[a:row]

train_labels = train_data["HomeWin"]
train_labels = train_labels.to_numpy(dtype=bool)
train_data = train_data.drop(columns=["HomeWin"])

test_labels = test_data["HomeWin"]
test_labels = test_labels.to_numpy(dtype=bool)
test_data = test_data.drop(columns=["HomeWin"])

x,y = train_data.shape
w,z = test_data.shape

for i in range(z):
    test_data.iloc[:,i] = test_data.iloc[:,i] / test_data.iloc[:,i].max()
for i in range(y):
    train_data.iloc[:,i] = train_data.iloc[:,i] / train_data.iloc[:,i].max()

row_t, col_t = train_data.shape

test_data
train_data = train_data.values
test_data = test_data.values
# Out:
#                                Date            Home/Neutral  HomeWin  Home  \
# Atlanta Hawks       Thu Oct 24 2019         Detroit Pistons    False     0
# Atlanta Hawks       Tue Oct 29 2019              Miami Heat     True     0
# Atlanta Hawks       Sun Nov 10 2019  Portland Trail Blazers     True     0
# Atlanta Hawks       Tue Nov 12 2019          Denver Nuggets    False     0
# Atlanta Hawks       Thu Nov 14 2019            Phoenix Suns     True     0
# Atlanta Hawks       Sat Nov 16 2019    Los Angeles Clippers     True     0
# Atlanta Hawks       Sun Nov 17 2019      Los Angeles Lakers     True     0
# Atlanta Hawks       Fri Nov 22 2019         Detroit Pistons     True     0
# Atlanta Hawks       Wed Nov 27 2019         Milwaukee Bucks     True     0
# Atlanta Hawks       Fri Nov 29 2019          Indiana Pacers     True     0
# Atlanta Hawks       Sat Nov 30 2019         Houston Rockets     True     0
# Atlanta Hawks        Sun Dec 8 2019       Charlotte Hornets    False     0
# Atlanta Hawks       Tue Dec 10 2019              Miami Heat     True     0
# Atlanta Hawks       Wed Dec 11 2019           Chicago Bulls     True     0
# Atlanta Hawks       Tue Dec 17 2019         New York Knicks     True     0
# Atlanta Hawks       Sat Dec 21 2019           Brooklyn Nets     True     0
# Atlanta Hawks       Mon Dec 23 2019     Cleveland Cavaliers     True     0
# Boston Celtics      Wed Oct 23 2019      Philadelphia 76ers     True     0
# Boston Celtics      Sat Oct 26 2019         New York Knicks    False     0
# Boston Celtics       Tue Nov 5 2019     Cleveland Cavaliers    False     0
# Boston Celtics       Thu Nov 7 2019       Charlotte Hornets    False     0
# Boston Celtics       Sat Nov 9 2019       San Antonio Spurs    False     0
# Boston Celtics      Fri Nov 15 2019   Golden State Warriors    False     0
# Boston Celtics      Sun Nov 17 2019        Sacramento Kings     True     0
# Boston Celtics      Mon Nov 18 2019            Phoenix Suns    False     0
# Boston Celtics      Wed Nov 20 2019    Los Angeles Clippers     True     0
# Boston Celtics      Fri Nov 22 2019          Denver Nuggets     True     0
# Boston Celtics      Fri Nov 29 2019           Brooklyn Nets     True     0
# Boston Celtics       Sun Dec 1 2019         New York Knicks    False     0
# Boston Celtics      Wed Dec 11 2019          Indiana Pacers     True     0
# ...                             ...                     ...      ...   ...
# Utah Jazz           Mon Nov 11 2019   Golden State Warriors    False     0
# Utah Jazz           Fri Nov 15 2019       Memphis Grizzlies     True     0
# Utah Jazz           Wed Nov 20 2019  Minnesota Timberwolves    False     0
# Utah Jazz           Mon Nov 25 2019         Milwaukee Bucks     True     0
# Utah Jazz           Wed Nov 27 2019          Indiana Pacers     True     0
# Utah Jazz           Fri Nov 29 2019       Memphis Grizzlies    False     0
# Utah Jazz            Sun Dec 1 2019         Toronto Raptors     True     0
# Utah Jazz            Mon Dec 2 2019      Philadelphia 76ers     True     0
# Utah Jazz           Wed Dec 11 2019  Minnesota Timberwolves    False     0
# Utah Jazz           Thu Dec 19 2019           Atlanta Hawks    False     0
# Utah Jazz           Sat Dec 21 2019       Charlotte Hornets    False     0
# Utah Jazz           Mon Dec 23 2019              Miami Heat     True     0
# Washington Wizards  Wed Oct 23 2019        Dallas Mavericks     True     0
# Washington Wizards  Fri Oct 25 2019   Oklahoma City Thunder    False     0
# Washington Wizards  Sat Oct 26 2019       San Antonio Spurs     True     0
# Washington Wizards   Wed Nov 6 2019          Indiana Pacers     True     0
# Washington Wizards  Wed Nov 13 2019          Boston Celtics     True     0
# Washington Wizards  Fri Nov 15 2019  Minnesota Timberwolves    False     0
# Washington Wizards  Sun Nov 17 2019           Orlando Magic     True     0
# Washington Wizards  Tue Nov 26 2019          Denver Nuggets     True     0
# Washington Wizards  Wed Nov 27 2019            Phoenix Suns    False     0
# Washington Wizards  Fri Nov 29 2019      Los Angeles Lakers     True     0
# Washington Wizards   Sun Dec 1 2019    Los Angeles Clippers     True     0
# Washington Wizards   Fri Dec 6 2019              Miami Heat     True     0
# Washington Wizards  Tue Dec 10 2019       Charlotte Hornets     True     0
# Washington Wizards  Sat Dec 14 2019       Memphis Grizzlies     True     0
# Washington Wizards  Mon Dec 16 2019         Detroit Pistons    False     0
# Washington Wizards  Fri Dec 20 2019         Toronto Raptors     True     0
# Washington Wizards  Sat Dec 21 2019      Philadelphia 76ers     True     0
# Washington Wizards  Mon Dec 23 2019         New York Knicks    False     0
#
#                     FG_A  FGA_A  FG%_A  3P_A  3PA_A  3P%_A  ...  FT%_B  ORB_B  \
# Atlanta Hawks       40.1   89.2  0.449  10.9   34.0  0.320  ...  0.739    9.7
# Atlanta Hawks       40.1   89.2  0.449  10.9   34.0  0.320  ...  0.766    8.9
# Atlanta Hawks       40.1   89.2  0.449  10.9   34.0  0.320  ...  0.823   10.2
# Atlanta Hawks       40.1   89.2  0.449  10.9   34.0  0.320  ...  0.751   11.1
# Atlanta Hawks       40.1   89.2  0.449  10.9   34.0  0.320  ...  0.804    9.6
# Atlanta Hawks       40.1   89.2  0.449  10.9   34.0  0.320  ...  0.782   11.0
# Atlanta Hawks       40.1   89.2  0.449  10.9   34.0  0.320  ...  0.729   10.1
# Atlanta Hawks       40.1   89.2  0.449  10.9   34.0  0.320  ...  0.739    9.7
# Atlanta Hawks       40.1   89.2  0.449  10.9   34.0  0.320  ...  0.726   10.0
# Atlanta Hawks       40.1   89.2  0.449  10.9   34.0  0.320  ...  0.807    9.4
# Atlanta Hawks       40.1   89.2  0.449  10.9   34.0  0.320  ...  0.788   11.4
# Atlanta Hawks       40.1   89.2  0.449  10.9   34.0  0.320  ...  0.742   11.3
# Atlanta Hawks       40.1   89.2  0.449  10.9   34.0  0.320  ...  0.766    8.9
# Atlanta Hawks       40.1   89.2  0.449  10.9   34.0  0.320  ...  0.765   10.2
# Atlanta Hawks       40.1   89.2  0.449  10.9   34.0  0.320  ...  0.683   12.2
# Atlanta Hawks       40.1   89.2  0.449  10.9   34.0  0.320  ...  0.750   10.9
# Atlanta Hawks       40.1   89.2  0.449  10.9   34.0  0.320  ...  0.759   10.8
# Boston Celtics      40.4   89.1  0.454  12.2   34.4  0.355  ...  0.742    9.7
# Boston Celtics      40.4   89.1  0.454  12.2   34.4  0.355  ...  0.683   12.2
# Boston Celtics      40.4   89.1  0.454  12.2   34.4  0.355  ...  0.759   10.8
# Boston Celtics      40.4   89.1  0.454  12.2   34.4  0.355  ...  0.742   11.3
# Boston Celtics      40.4   89.1  0.454  12.2   34.4  0.355  ...  0.782   10.3
# Boston Celtics      40.4   89.1  0.454  12.2   34.4  0.355  ...  0.813   10.6
# Boston Celtics      40.4   89.1  0.454  12.2   34.4  0.355  ...  0.789    9.8
# Boston Celtics      40.4   89.1  0.454  12.2   34.4  0.355  ...  0.804    9.6
# Boston Celtics      40.4   89.1  0.454  12.2   34.4  0.355  ...  0.782   11.0
# Boston Celtics      40.4   89.1  0.454  12.2   34.4  0.355  ...  0.751   11.1
# Boston Celtics      40.4   89.1  0.454  12.2   34.4  0.355  ...  0.750   10.9
# Boston Celtics      40.4   89.1  0.454  12.2   34.4  0.355  ...  0.683   12.2
# Boston Celtics      40.4   89.1  0.454  12.2   34.4  0.355  ...  0.807    9.4
# ...                  ...    ...    ...   ...    ...    ...  ...    ...    ...
# Utah Jazz           38.3   83.7  0.457  12.1   31.5  0.383  ...  0.813   10.6
# Utah Jazz           38.3   83.7  0.457  12.1   31.5  0.383  ...  0.771   10.0
# Utah Jazz           38.3   83.7  0.457  12.1   31.5  0.383  ...  0.760   11.1
# Utah Jazz           38.3   83.7  0.457  12.1   31.5  0.383  ...  0.726   10.0
# Utah Jazz           38.3   83.7  0.457  12.1   31.5  0.383  ...  0.807    9.4
# Utah Jazz           38.3   83.7  0.457  12.1   31.5  0.383  ...  0.771   10.0
# Utah Jazz           38.3   83.7  0.457  12.1   31.5  0.383  ...  0.805    9.6
# Utah Jazz           38.3   83.7  0.457  12.1   31.5  0.383  ...  0.742    9.7
# Utah Jazz           38.3   83.7  0.457  12.1   31.5  0.383  ...  0.760   11.1
# Utah Jazz           38.3   83.7  0.457  12.1   31.5  0.383  ...  0.754    9.8
# Utah Jazz           38.3   83.7  0.457  12.1   31.5  0.383  ...  0.742   11.3
# Utah Jazz           38.3   83.7  0.457  12.1   31.5  0.383  ...  0.766    8.9
# Washington Wizards  43.5   92.9  0.468  13.1   35.2  0.372  ...  0.776   10.5
# Washington Wizards  43.5   92.9  0.468  13.1   35.2  0.372  ...  0.799    7.8
# Washington Wizards  43.5   92.9  0.468  13.1   35.2  0.372  ...  0.782   10.3
# Washington Wizards  43.5   92.9  0.468  13.1   35.2  0.372  ...  0.807    9.4
# Washington Wizards  43.5   92.9  0.468  13.1   35.2  0.372  ...  0.801   10.5
# Washington Wizards  43.5   92.9  0.468  13.1   35.2  0.372  ...  0.760   11.1
# Washington Wizards  43.5   92.9  0.468  13.1   35.2  0.372  ...  0.780   10.5
# Washington Wizards  43.5   92.9  0.468  13.1   35.2  0.372  ...  0.751   11.1
# Washington Wizards  43.5   92.9  0.468  13.1   35.2  0.372  ...  0.804    9.6
# Washington Wizards  43.5   92.9  0.468  13.1   35.2  0.372  ...  0.729   10.1
# Washington Wizards  43.5   92.9  0.468  13.1   35.2  0.372  ...  0.782   11.0
# Washington Wizards  43.5   92.9  0.468  13.1   35.2  0.372  ...  0.766    8.9
# Washington Wizards  43.5   92.9  0.468  13.1   35.2  0.372  ...  0.742   11.3
# Washington Wizards  43.5   92.9  0.468  13.1   35.2  0.372  ...  0.771   10.0
# Washington Wizards  43.5   92.9  0.468  13.1   35.2  0.372  ...  0.739    9.7
# Washington Wizards  43.5   92.9  0.468  13.1   35.2  0.372  ...  0.805    9.6
# Washington Wizards  43.5   92.9  0.468  13.1   35.2  0.372  ...  0.742    9.7
# Washington Wizards  43.5   92.9  0.468  13.1   35.2  0.372  ...  0.683   12.2
#
#                     DRB_B  TRB_B  AST_B  STL_B  BLK_B  TOV_B  PF_B  PTS_B
# Atlanta Hawks        33.2   42.9   24.7    6.9    4.9   16.2  19.0  108.4
# Atlanta Hawks        36.1   45.0   25.5    8.2    4.4   16.9  21.3  112.7
# Atlanta Hawks        36.5   46.8   20.0    6.0    6.6   13.7  23.2  112.8
# Atlanta Hawks        35.0   46.1   26.4    7.7    4.9   14.0  19.7  106.9
# Atlanta Hawks        33.6   43.2   28.5    7.9    4.0   14.4  23.3  114.5
# Atlanta Hawks        37.2   48.2   23.0    7.9    5.3   16.3  22.7  115.2
# Atlanta Hawks        35.4   45.5   26.2    8.6    7.1   15.3  20.2  112.6
# Atlanta Hawks        33.2   42.9   24.7    6.9    4.9   16.2  19.0  108.4
# Atlanta Hawks        40.9   50.9   25.8    8.0    5.8   14.6  20.4  120.7
# Atlanta Hawks        34.9   44.3   25.1    7.0    5.2   13.6  20.5  109.4
# Atlanta Hawks        36.4   47.9   21.7    8.5    5.1   15.4  22.0  119.8
# Atlanta Hawks        31.9   43.2   23.7    6.7    4.5   15.3  19.5  104.5
# Atlanta Hawks        36.1   45.0   25.5    8.2    4.4   16.9  21.3  112.7
# Atlanta Hawks        33.4   43.5   23.3   10.0    4.4   15.5  22.9  105.6
# Atlanta Hawks        33.2   45.5   20.6    7.9    4.6   14.2  22.8  103.1
# Atlanta Hawks        37.3   48.2   23.9    6.9    5.0   15.9  21.7  111.5
# Atlanta Hawks        33.4   44.2   21.6    7.2    3.3   15.9  17.5  103.9
# Boston Celtics       36.1   45.8   26.3    8.7    5.9   16.0  21.6  108.8
# Boston Celtics       33.2   45.5   20.6    7.9    4.6   14.2  22.8  103.1
# Boston Celtics       33.4   44.2   21.6    7.2    3.3   15.9  17.5  103.9
# Boston Celtics       31.9   43.2   23.7    6.7    4.5   15.3  19.5  104.5
# Boston Celtics       36.3   46.6   24.3    6.8    5.9   13.7  19.4  112.0
# Boston Celtics       32.7   43.3   23.8    8.3    4.7   14.7  19.7  104.6
# Boston Celtics       31.5   41.3   22.5    7.7    4.5   15.4  21.2  104.8
# Boston Celtics       33.6   43.2   28.5    7.9    4.0   14.4  23.3  114.5
# Boston Celtics       37.2   48.2   23.0    7.9    5.3   16.3  22.7  115.2
# Boston Celtics       35.0   46.1   26.4    7.7    4.9   14.0  19.7  106.9
# Boston Celtics       37.3   48.2   23.9    6.9    5.0   15.9  21.7  111.5
# Boston Celtics       33.2   45.5   20.6    7.9    4.6   14.2  22.8  103.1
# Boston Celtics       34.9   44.3   25.1    7.0    5.2   13.6  20.5  109.4
# ...                   ...    ...    ...    ...    ...    ...   ...    ...
# Utah Jazz            32.7   43.3   23.8    8.3    4.7   14.7  19.7  104.6
# Utah Jazz            35.1   45.2   26.8    8.1    5.2   16.0  22.4  110.5
# Utah Jazz            35.1   46.2   22.7    8.1    6.1   15.3  21.7  113.6
# Utah Jazz            40.9   50.9   25.8    8.0    5.8   14.6  20.4  120.7
# Utah Jazz            34.9   44.3   25.1    7.0    5.2   13.6  20.5  109.4
# Utah Jazz            35.1   45.2   26.8    8.1    5.2   16.0  22.4  110.5
# Utah Jazz            36.5   46.2   25.3    8.4    5.3   15.0  21.2  112.0
# Utah Jazz            36.1   45.8   26.3    8.7    5.9   16.0  21.6  108.8
# Utah Jazz            35.1   46.2   22.7    8.1    6.1   15.3  21.7  113.6
# Utah Jazz            32.0   41.8   23.5    8.3    4.8   17.2  22.9  108.4
# Utah Jazz            31.9   43.2   23.7    6.7    4.5   15.3  19.5  104.5
# Utah Jazz            36.1   45.0   25.5    8.2    4.4   16.9  21.3  112.7
# Washington Wizards   37.4   47.9   24.6    6.4    4.6   12.8  19.5  117.6
# Washington Wizards   34.6   42.3   21.8    7.4    5.1   14.6  19.8  108.9
# Washington Wizards   36.3   46.6   24.3    6.8    5.9   13.7  19.4  112.0
# Washington Wizards   34.9   44.3   25.1    7.0    5.2   13.6  20.5  109.4
# Washington Wizards   35.2   45.7   23.1    8.3    6.0   13.6  21.5  110.9
# Washington Wizards   35.1   46.2   22.7    8.1    6.1   15.3  21.7  113.6
# Washington Wizards   34.0   44.4   22.7    8.2    6.4   13.0  18.1  103.5
# Washington Wizards   35.0   46.1   26.4    7.7    4.9   14.0  19.7  106.9
# Washington Wizards   33.6   43.2   28.5    7.9    4.0   14.4  23.3  114.5
# Washington Wizards   35.4   45.5   26.2    8.6    7.1   15.3  20.2  112.6
# Washington Wizards   37.2   48.2   23.0    7.9    5.3   16.3  22.7  115.2
# Washington Wizards   36.1   45.0   25.5    8.2    4.4   16.9  21.3  112.7
# Washington Wizards   31.9   43.2   23.7    6.7    4.5   15.3  19.5  104.5
# Washington Wizards   35.1   45.2   26.8    8.1    5.2   16.0  22.4  110.5
# Washington Wizards   33.2   42.9   24.7    6.9    4.9   16.2  19.0  108.4
# Washington Wizards   36.5   46.2   25.3    8.4    5.3   15.0  21.2  112.0
# Washington Wizards   36.1   45.8   26.3    8.7    5.9   16.0  21.6  108.8
# Washington Wizards   33.2   45.5   20.6    7.9    4.6   14.2  22.8  103.1
#
# [454 rows x 46 columns]

# %%
# creating the model
model = keras.Sequential([
    keras.layers.Input(col_t),
    keras.layers.Dense(512, activation='tanh'),
    keras.layers.Dense(256, activation='tanh'),
    keras.layers.Dense(2, activation='softmax')
])
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# %%
model.fit(train_data, train_labels, epochs=5)
# Out:
# Train on 1222 samples
# Epoch 1/5
# 1222/1222 [==============================] - 0s 151us/sample - loss: 0.6579 - accuracy: 0.5949
# Epoch 2/5
# 1222/1222 [==============================] - 0s 140us/sample - loss: 0.6453 - accuracy: 0.6375
# Epoch 3/5
# 1222/1222 [==============================] - 0s 144us/sample - loss: 0.6962 - accuracy: 0.5646
# Epoch 4/5
# 1222/1222 [==============================] - 0s 161us/sample - loss: 0.6530 - accuracy: 0.6023
# Epoch 5/5
# 1222/1222 [==============================] - 0s 281us/sample - loss: 0.6645 - accuracy: 0.5949

# %%
model.evaluate(test_data,test_labels)
# Out:
# 4888/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# [0.6376924823036756, 0.6450491]

# %%
predict
# Out:
# array([[0.53158   , 0.46842003],
#        [0.63339734, 0.36660266],
#        [0.3908513 , 0.6091486 ],
#        ...,
#        [0.6310911 , 0.36890885],
#        [0.52146006, 0.47853997],
#        [0.38815224, 0.61184776]], dtype=float32)
