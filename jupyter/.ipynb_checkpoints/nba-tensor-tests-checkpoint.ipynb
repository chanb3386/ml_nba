# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
LABELS = [True, False]
# True = home win, False = away win
LABEL_COLUMN = "WINorLOSS"

TEAM_DICT = {
             "MIL" : "Milwaukee Bucks",
             "MIA" : "Miami Heat",
             "BOS" : "Boston Celtics",
             "TOR" : "Toronto Raptors",
             "PHI" : "Philidelphia 76ers",
             "IND" : "Indiana Pacers",
             "BRK" : "Brooklyn Nets",
             "ORL" : "Orlando Magic",
             "CHO" : "Charlotte Hornets",
             "CHI" : "Chicago Bulls",
             "DET" : "Detroit Pistons",
             "WAS" : "Washington Wizards",
             "CLE" : "Cleveland Cavaliers",
             "NYK" : "New York Knicks",
             "ATL" : "Atlanta Hawks",
             "LAL" : "Los Angeles Lakers",
             "DEN" : "Denver Nuggets",
             "HOU" : "Houston Rockets",
             "LAC" : "Los Angeles Clippers",
             "DAL" : "Dallas Mavericks",
             "UTA" : "Utah Jazz",
             "OKC" : "Oklahoma City Thunder",
             "POR" : "Portland Trail Blazers",
             "SAS" : "San Antonio Spurs",
             "SAC" : "Sacramento Kings",
             "PHO" : "Phoenix Suns",
             "MEM" : "Memphis Grizzlies",
             "MIN" : "Minnesota Timberwolves",
             "NOP" : "New Orleans Pelicans",
             "GSW" : "Golden State Warriors"
            }

BOOL_DICT = {1 : True, 0 : False}

# %%
data2 = pd.read_csv("../data/games/nba-games-results-2014-2018.csv",index_col=1)

# removing and cleaning data
data2 = data2.drop(columns=['Unnamed: 0','Game'])

data2['Home'] = pd.Categorical(data2['Home'])
data2['Home'] = data2.Home.cat.codes
data2['WINorLOSS'] = pd.Categorical(data2['WINorLOSS'])
data2['WINorLOSS'] = data2.WINorLOSS.cat.codes
data2.index = data2.index.map(TEAM_DICT)
data2['Opponent'] = data2['Opponent'].map(TEAM_DICT)
#data2.drop(columns=[''])

data3 = pd.read_csv("../data/games/nba-games-2019-oct-nov-dec.txt", index_col=4)
data3 = data3.drop(columns=['Start (ET)','Unnamed: 6','Unnamed: 7', 'Attend.', 'Notes'])

data4 = pd.read_csv("../data/league-stats/team-per-game.txt", index_col=1)
data4 = data4.drop(columns=['Rk', 'G', 'MP'])

data2015 = pd.read_csv("../data/league-stats/team-per-game-14-15.txt",index_col=1)
data2015 = data2015.drop(columns=['Rk','G', 'MP'])

data2016 = pd.read_csv("../data/league-stats/team-per-game-15-16.txt",index_col=1)
data2016 = data2016.drop(columns=['Rk','G', 'MP'])

data2017 = pd.read_csv("../data/league-stats/team-per-game-16-17.txt",index_col=1)
data2017 = data2017.drop(columns=['Rk','G', 'MP'])

data2018 = pd.read_csv("../data/league-stats/team-per-game-17-18.txt",index_col=1)
data2018 = data2018.drop(columns=['Rk','G', 'MP'])

dataOppStats2020 = pd.read_csv("../data/league-stats/opponent-stats.txt", index_col=1)
dataOppStats2020 = dataOppStats2020.drop(columns=['Rk', 'G', 'MP'])

#data4['FG'] = data4['FG'] / data4['FG'].max()
#data4.iloc[:,0]
x,y = data4.shape


#standardizing data
#for i in range(y):
#    data4.iloc[:,i] = data4.iloc[:,i] / data4.iloc[:,i].max()

data3["HomeWin"] = data3["PTS"] > data3["PTS.1"]
data3 = data3.drop(columns=["PTS", "PTS.1"])

w,z = data2.shape

data2 = data2[data2["Home"] == 1]
data2 = data2.drop(columns=['Home'])
data2 = data2.rename(columns = {"Opponent" : "Visitor/Neutral",
                                "WINorLOSS" : "HomeWin"})
data2 = data2.drop(columns = data2.columns[3:])
data2["HomeWin"] = data2["HomeWin"].map(BOOL_DICT)
#data2["Date"][0][0:4] == '2014'

def splitDate(date):
    return date.split('-')

data2




#input for prediction

#season stats (past 5 games?), opponent, home/away

#input: team stats (weighted average), opp stats (weighted average), home/away, rest days
# Out:
#                           Date         Visitor/Neutral  HomeWin
# Team
# Atlanta Hawks       2014-11-01          Indiana Pacers     True
# Atlanta Hawks       2014-11-08         New York Knicks     True
# Atlanta Hawks       2014-11-12               Utah Jazz     True
# Atlanta Hawks       2014-11-14              Miami Heat     True
# Atlanta Hawks       2014-11-18      Los Angeles Lakers    False
# Atlanta Hawks       2014-11-21         Detroit Pistons     True
# Atlanta Hawks       2014-11-26         Toronto Raptors    False
# Atlanta Hawks       2014-11-28    New Orleans Pelicans     True
# Atlanta Hawks       2014-11-29       Charlotte Hornets     True
# Atlanta Hawks       2014-12-02          Boston Celtics     True
# Atlanta Hawks       2014-12-07          Denver Nuggets     True
# Atlanta Hawks       2014-12-10      Philidelphia 76ers     True
# Atlanta Hawks       2014-12-12           Orlando Magic     True
# Atlanta Hawks       2014-12-15           Chicago Bulls     True
# Atlanta Hawks       2014-12-23    Los Angeles Clippers     True
# Atlanta Hawks       2014-12-26         Milwaukee Bucks    False
# Atlanta Hawks       2014-12-30     Cleveland Cavaliers     True
# Atlanta Hawks       2015-01-07       Memphis Grizzlies     True
# Atlanta Hawks       2015-01-11      Washington Wizards     True
# Atlanta Hawks       2015-01-19         Detroit Pistons     True
# Atlanta Hawks       2015-01-21          Indiana Pacers     True
# Atlanta Hawks       2015-01-23   Oklahoma City Thunder     True
# Atlanta Hawks       2015-01-25  Minnesota Timberwolves     True
# Atlanta Hawks       2015-01-28           Brooklyn Nets     True
# Atlanta Hawks       2015-01-30  Portland Trail Blazers     True
# Atlanta Hawks       2015-01-31      Philidelphia 76ers     True
# Atlanta Hawks       2015-02-04      Washington Wizards     True
# Atlanta Hawks       2015-02-06   Golden State Warriors     True
# Atlanta Hawks       2015-02-20         Toronto Raptors    False
# Atlanta Hawks       2015-02-25        Dallas Mavericks     True
# ...                        ...                     ...      ...
# Washington Wizards  2017-12-13       Memphis Grizzlies     True
# Washington Wizards  2017-12-15    Los Angeles Clippers     True
# Washington Wizards  2017-12-17     Cleveland Cavaliers    False
# Washington Wizards  2017-12-19    New Orleans Pelicans     True
# Washington Wizards  2017-12-23           Orlando Magic     True
# Washington Wizards  2017-12-29         Houston Rockets     True
# Washington Wizards  2017-12-31           Chicago Bulls     True
# Washington Wizards  2018-01-03         New York Knicks     True
# Washington Wizards  2018-01-06         Milwaukee Bucks    False
# Washington Wizards  2018-01-10               Utah Jazz    False
# Washington Wizards  2018-01-12           Orlando Magic     True
# Washington Wizards  2018-01-13           Brooklyn Nets     True
# Washington Wizards  2018-01-15         Milwaukee Bucks    False
# Washington Wizards  2018-01-30   Oklahoma City Thunder     True
# Washington Wizards  2018-02-01         Toronto Raptors     True
# Washington Wizards  2018-02-08          Boston Celtics    False
# Washington Wizards  2018-02-23       Charlotte Hornets    False
# Washington Wizards  2018-02-25      Philidelphia 76ers     True
# Washington Wizards  2018-02-28   Golden State Warriors    False
# Washington Wizards  2018-03-02         Toronto Raptors    False
# Washington Wizards  2018-03-04          Indiana Pacers    False
# Washington Wizards  2018-03-06              Miami Heat     True
# Washington Wizards  2018-03-13  Minnesota Timberwolves    False
# Washington Wizards  2018-03-17          Indiana Pacers     True
# Washington Wizards  2018-03-23          Denver Nuggets    False
# Washington Wizards  2018-03-25         New York Knicks    False
# Washington Wizards  2018-03-27       San Antonio Spurs     True
# Washington Wizards  2018-03-31       Charlotte Hornets     True
# Washington Wizards  2018-04-06           Atlanta Hawks    False
# Washington Wizards  2018-04-10          Boston Celtics     True
#
# [4920 rows x 3 columns]

# %%
d5 = data3.join(data4,lsuffix="_d3", rsuffix="_d4")
d6 = d5.join(data4, on='Visitor/Neutral', lsuffix="_home",rsuffix="_away")
d7 = d6.join(dataOppStats2020)
d8 = d7.join(dataOppStats2020, on='Visitor/Neutral', lsuffix='_homeOppStat', rsuffix='_awayOppStats')
# has teams, date, winner, all relevant stats: need to add rest days, recency bias, any other stats I may want (injury?)
row, col = d8.shape
#need to use later for ^^^^
d8 = d8.drop(columns=['Date'])



d8 = d8.sample(frac=1)
a = int(row * .2)
train_data = d8.iloc[0:a]
test_data = d8.iloc[a:row]

train_labels = train_data["HomeWin"]
train_labels = train_labels.to_numpy(dtype=bool)
train_data = train_data.drop(columns=["HomeWin"])

test_labels = test_data["HomeWin"]
test_labels = test_labels.to_numpy(dtype=bool)
test_data = test_data.drop(columns=["HomeWin"])

test_data = test_data.drop(columns=['Visitor/Neutral'])
train_data = train_data.drop(columns=['Visitor/Neutral'])

row_t, col_t = train_data.shape

train_data = train_data.values
test_data = test_data.values

# %%
# creating the model
model = keras.Sequential([
    keras.layers.Dense(col_t-1),
    keras.layers.Dense(256, activation='tanh'),
    keras.layers.Dense(64, activation='tanh'),
    keras.layers.Dense(2, activation='softmax')
])
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# %%
model.fit(train_data, train_labels, epochs=5)
# Out:
# Train on 90 samples
# Epoch 1/5
# 90/90 [==============================] - 1s 7ms/sample - loss: 1.4332 - accuracy: 0.4444
# Epoch 2/5
# 90/90 [==============================] - 0s 141us/sample - loss: 0.7521 - accuracy: 0.5778
# Epoch 3/5
# 90/90 [==============================] - 0s 130us/sample - loss: 0.7553 - accuracy: 0.4667
# Epoch 4/5
# 90/90 [==============================] - 0s 150us/sample - loss: 0.6815 - accuracy: 0.5222
# Epoch 5/5
# 90/90 [==============================] - 0s 95us/sample - loss: 0.6671 - accuracy: 0.6556

# %%
model.evaluate(test_data,test_labels)
# Out:
# 364/1 [========================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [0.6741838645149063, 0.6593407]
