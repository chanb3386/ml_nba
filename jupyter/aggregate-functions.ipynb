# %%
import pandas as pd
a = pd.read_csv("../data/team-player-stats/bucks.txt", index_col=1)
b = pd.read_csv("../data/league-stats/team-per-game.txt", index_col = 1)
b.loc
# Out:
#                           Rk   G     MP    FG   FGA    FG%    3P   3PA    3P%  \
# Team
# Milwaukee Bucks          1.0  29  240.9  44.0  91.0  0.484  14.2  39.4  0.360
# Los Angeles Clippers     2.0  30  240.8  41.3  89.8  0.460  11.8  32.6  0.363
# New Orleans Pelicans     3.0  30  242.5  41.0  91.9  0.446  13.9  38.5  0.361
# Houston Rockets          4.0  28  241.8  41.1  91.3  0.451  15.7  45.4  0.346
# Dallas Mavericks         5.0  28  241.8  41.8  89.7  0.466  14.8  40.6  0.365
# Portland Trail Blazers   6.0  29  240.9  41.3  91.2  0.453  12.3  33.6  0.366
# Miami Heat               7.0  29  244.3  39.8  83.8  0.474  12.8  33.1  0.385
# Los Angeles Lakers       8.0  29  240.9  42.6  88.0  0.484  10.9  30.6  0.357
# Philadelphia 76ers       9.0  30  240.8  40.7  86.3  0.471  10.7  29.7  0.360
# Charlotte Hornets       10.0  31  240.8  37.8  86.5  0.437  12.7  35.3  0.360
# Phoenix Suns            11.0  28  242.7  41.3  90.7  0.455  12.6  35.6  0.353
# ...
