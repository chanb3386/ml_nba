# %%
import pandas as pd

# %%
a = pd.read_csv("data/bucks.txt", index_col=1)
a
# Out:
#                                   Rk  Age   G  GS    MP    FG   FGA    FG%  \
# Name
# Giannis Antetokounmpo\antetgi01    1   25  28  28  31.3  11.7  20.8  0.565
# Khris Middleton\middlkh01          2   28  22  19  27.7   6.7  13.6  0.493
# Eric Bledsoe\bledser01             3   30  26  26  26.7   5.7  11.8  0.477
# Brook Lopez\lopezbr01              4   31  27  27  26.2   3.2   8.4  0.382
# Wesley Matthews\matthwe02          5   33  29  29  24.0   2.7   6.2  0.431
# Donte DiVincenzo\divindo01         6   23  26  13  21.7   3.2   7.3  0.429
# George Hill\hillge01               7   33  27   0  21.7   3.5   6.5  0.537
# Sterling Brown\brownst02           8   24  21   0  17.0   2.0   5.0  0.394
# Pat Connaughton\connapa01          9   27  27   0  16.9   1.9   4.0  0.486
# Ersan İlyasova\ilyaser01          10   32  26   1  16.3   2.8   5.7  0.503
# Kyle Korver\korveky01             11   38  24   0  15.7   1.9   4.9  0.393
# ...
